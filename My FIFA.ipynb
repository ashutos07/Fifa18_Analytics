# %% [markdown]
# ## 1. Initialization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df= pd.read_csv("FIFA 2018 Statistics.csv")

# %%
df.head()
# Out:
#          Date          Team      Opponent  Goal Scored  Ball Possession %  \
# 0  14-06-2018        Russia  Saudi Arabia            5                 40
# 1  14-06-2018  Saudi Arabia        Russia            0                 60
# 2  15-06-2018         Egypt       Uruguay            0                 43
# 3  15-06-2018       Uruguay         Egypt            1                 57
# 4  15-06-2018       Morocco          Iran            0                 64
#
#    Attempts  On-Target  Off-Target  Blocked  Corners  ...  Yellow Card  \
# 0        13          7           3        3        6  ...            0
# 1         6          0           3        3        2  ...            0
# 2         8          3           3        2        0  ...            2
# 3        14          4           6        4        5  ...            0
# 4        13          3           6        4        5  ...            1
#
#    Yellow & Red  Red  Man of the Match  1st Goal        Round  PSO  \
# ...

# %% [markdown]
# ## 2. Assessment

# %%
df.shape
# Out:
# (128, 27)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 27 columns):
# Date                      128 non-null object
# Team                      128 non-null object
# Opponent                  128 non-null object
# Goal Scored               128 non-null int64
# Ball Possession %         128 non-null int64
# Attempts                  128 non-null int64
# On-Target                 128 non-null int64
# Off-Target                128 non-null int64
# Blocked                   128 non-null int64
# Corners                   128 non-null int64
# Offsides                  128 non-null int64
# Free Kicks                128 non-null int64
# Saves                     128 non-null int64
# Pass Accuracy %           128 non-null int64
# Passes                    128 non-null int64
# Distance Covered (Kms)    128 non-null int64
# Fouls Committed           128 non-null int64
# Yellow Card               128 non-null int64
# ...

# %%
df.describe()
# Out:
#        Goal Scored  Ball Possession %    Attempts   On-Target  Off-Target  \
# count   128.000000         128.000000  128.000000  128.000000  128.000000
# mean      1.320312          49.992188   12.593750    3.914062    5.273438
# std       1.156519          10.444074    5.245827    2.234403    2.409675
# min       0.000000          25.000000    3.000000    0.000000    1.000000
# 25%       0.000000          42.000000    9.000000    2.000000    4.000000
# 50%       1.000000          50.000000   12.000000    3.500000    5.000000
# 75%       2.000000          58.000000   15.000000    5.000000    7.000000
# max       6.000000          75.000000   26.000000   12.000000   11.000000
#
#           Blocked     Corners    Offsides  Free Kicks       Saves  ...  \
# count  128.000000  128.000000  128.000000  128.000000  128.000000  ...
# mean     3.359375    4.718750    1.343750   14.890625    2.726562  ...
# std      2.403195    2.446072    1.193404    4.724262    2.049447  ...
# ...

# %% [markdown]
# ## 3. Data Cleaning

# %% [markdown]
# #### edting columns

# %%
df_copy= df.copy()

# %%
list(df_copy)
# Out:
# ['Date',
#  'Team',
#  'Opponent',
#  'Goal Scored',
#  'Ball Possession %',
#  'Attempts',
#  'On-Target',
#  'Off-Target',
#  'Blocked',
#  'Corners',
#  'Offsides',
#  'Free Kicks',
#  'Saves',
#  'Pass Accuracy %',
#  'Passes',
#  'Distance Covered (Kms)',
#  'Fouls Committed',
#  'Yellow Card',
#  'Yellow & Red',
#  'Red',
#  'Man of the Match',
#  '1st Goal',
#  'Round',
#  'PSO',
#  'Goals in PSO',
#  'Own goals',
#  'Own goal Time']

# %%
df_copy.rename(columns={'Goal Scored':'Goal_Scored',
'Ball Possession %':'Ball_Possession',
'Free Kicks':'Free_Kicks',
'Pass Accuracy %':'Pass_Accuracy',
'Distance Covered (Kms)':'Distance_Covered',
'Fouls Committed':'Fouls_Committed',
'Yellow Card':'Yellow_Card',
'Yellow & Red':'Yellow & Red',
'Man of the Match':'Man_of_the_Match',
'1st Goal':'1st_Goals',
'Goals in PSO':'Goals_in_PSO',
'Own goals':'Own_goals',
'Own goal Time':'Own_goal_Time'}, inplace=True)

# %%
df_copy.head()
# Out:
#          Date          Team      Opponent  Goal_Scored  Ball_Possession  \
# 0  14-06-2018        Russia  Saudi Arabia            5               40
# 1  14-06-2018  Saudi Arabia        Russia            0               60
# 2  15-06-2018         Egypt       Uruguay            0               43
# 3  15-06-2018       Uruguay         Egypt            1               57
# 4  15-06-2018       Morocco          Iran            0               64
#
#    Attempts  On-Target  Off-Target  Blocked  Corners  ...  Yellow_Card  \
# 0        13          7           3        3        6  ...            0
# 1         6          0           3        3        2  ...            0
# 2         8          3           3        2        0  ...            2
# 3        14          4           6        4        5  ...            0
# 4        13          3           6        4        5  ...            1
#
#    Yellow & Red  Red  Man_of_the_Match  1st_Goals        Round  PSO  \
# ...

# %% [markdown]
# #### dealing with NaN
# converting NaN under Own_goals to 0

# %%
df_copy['Own_goals']=df_copy['Own_goals'].fillna(0)

# %%
df_copy
# Out:
#            Date            Team        Opponent  Goal_Scored  Ball_Possession  \
# 0    14-06-2018          Russia    Saudi Arabia            5               40
# 1    14-06-2018    Saudi Arabia          Russia            0               60
# 2    15-06-2018           Egypt         Uruguay            0               43
# 3    15-06-2018         Uruguay           Egypt            1               57
# 4    15-06-2018         Morocco            Iran            0               64
# 5    15-06-2018            Iran         Morocco            1               36
# 6    15-06-2018        Portugal           Spain            3               39
# 7    15-06-2018           Spain        Portugal            3               61
# 8    16-06-2018          France       Australia            2               51
# 9    16-06-2018       Australia          France            1               49
# 10   16-06-2018       Argentina         Iceland            1               72
# ...

# %% [markdown]
# #### dealing with Yes and No
# coverting 'Yes' and 'No' values of 'Man_of_the_Match' and 'PSO' to numeric values

# %%
df_copy['Man_of_the_Match']= df_copy['Man_of_the_Match'].map({'Yes':1,'No':0})

# %%
df_copy['PSO']=df_copy['PSO'].map({'Yes':1,'No':0})

# %%
df_copy.head()
# Out:
#          Date          Team      Opponent  Goal_Scored  Ball_Possession  \
# 0  14-06-2018        Russia  Saudi Arabia            5               40
# 1  14-06-2018  Saudi Arabia        Russia            0               60
# 2  15-06-2018         Egypt       Uruguay            0               43
# 3  15-06-2018       Uruguay         Egypt            1               57
# 4  15-06-2018       Morocco          Iran            0               64
#
#    Attempts  On-Target  Off-Target  Blocked  Corners  ...  Yellow_Card  \
# 0        13          7           3        3        6  ...            0
# 1         6          0           3        3        2  ...            0
# 2         8          3           3        2        0  ...            2
# 3        14          4           6        4        5  ...            0
# 4        13          3           6        4        5  ...            1
#
#    Yellow & Red  Red  Man_of_the_Match  1st_Goals        Round  PSO  \
# ...

# %% [markdown]
# #### dealing with unnecessary columns
# removing columns not required for this analysis

# %%
columns=['Own_goal_Time','1st_Goals']
df_copy.drop(columns,axis=1,inplace=True)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 25 columns):
# Date                128 non-null object
# Team                128 non-null object
# Opponent            128 non-null object
# Goal_Scored         128 non-null int64
# Ball_Possession     128 non-null int64
# Attempts            128 non-null int64
# On-Target           128 non-null int64
# Off-Target          128 non-null int64
# Blocked             128 non-null int64
# Corners             128 non-null int64
# Offsides            128 non-null int64
# Free_Kicks          128 non-null int64
# Saves               128 non-null int64
# Pass_Accuracy       128 non-null int64
# Passes              128 non-null int64
# Distance_Covered    128 non-null int64
# Fouls_Committed     128 non-null int64
# Yellow_Card         128 non-null int64
# Yellow & Red        128 non-null int64
# Red                 128 non-null int64
# Man_of_the_Match    128 non-null int64
# ...

# %% [markdown]
# #### dealing with mismatch
# converting datatypes

# %%
df_copy['Own_goals']=df_copy['Own_goals'].astype('int64')

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 25 columns):
# Date                128 non-null object
# Team                128 non-null object
# Opponent            128 non-null object
# Goal_Scored         128 non-null int64
# Ball_Possession     128 non-null int64
# Attempts            128 non-null int64
# On-Target           128 non-null int64
# Off-Target          128 non-null int64
# Blocked             128 non-null int64
# Corners             128 non-null int64
# Offsides            128 non-null int64
# Free_Kicks          128 non-null int64
# Saves               128 non-null int64
# Pass_Accuracy       128 non-null int64
# Passes              128 non-null int64
# Distance_Covered    128 non-null int64
# Fouls_Committed     128 non-null int64
# Yellow_Card         128 non-null int64
# Yellow & Red        128 non-null int64
# Red                 128 non-null int64
# Man_of_the_Match    128 non-null int64
# ...

# %%
df_copy['Date']=pd.to_datetime(df_copy['Date'])

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 25 columns):
# Date                128 non-null datetime64[ns]
# Team                128 non-null object
# Opponent            128 non-null object
# Goal_Scored         128 non-null int64
# Ball_Possession     128 non-null int64
# Attempts            128 non-null int64
# On-Target           128 non-null int64
# Off-Target          128 non-null int64
# Blocked             128 non-null int64
# Corners             128 non-null int64
# Offsides            128 non-null int64
# Free_Kicks          128 non-null int64
# Saves               128 non-null int64
# Pass_Accuracy       128 non-null int64
# Passes              128 non-null int64
# Distance_Covered    128 non-null int64
# Fouls_Committed     128 non-null int64
# Yellow_Card         128 non-null int64
# Yellow & Red        128 non-null int64
# Red                 128 non-null int64
# Man_of_the_Match    128 non-null int64
# ...

# %% [markdown]
# ## 4. Feature Engineering and Visualization

# %% [markdown]
# #### shot accuracy

# %%
df_copy['shot_accuracy']=df_copy['On-Target']/df_copy['Attempts']

# %% [markdown]
# #### conversion rate

# %%
df_copy['conversion_rate']=df_copy['Goal_Scored']/df_copy['Attempts']

# %%
sum=df_copy.groupby('Team')['Goal_Scored'].sum()

# %%
sum.plot.bar(figsize=(12,4))
plt.xlabel('Teams')
plt.ylabel('Goal Scored')
plt.title('Conversion')
# Out:
# Text(0.5,1,'Conversion')

# %% [markdown]
# ### some additional features
# created DataFrames to plot separately later on

# %%
#creating a DataFrame of number of goals scored by each team

goals=df_copy.groupby('Team')['Goal_Scored'].sum()
df_goals=pd.DataFrame(goals)
df_goals.head()
# Out:
#            Goal_Scored
# Team
# Argentina            6
# Australia            2
# Belgium             16
# Brazil               8
# Colombia             6

# %%
#creating a DataFrame of number of matches played by each team

matches=df_copy.groupby('Team')['Date'].count()
df_matches=pd.DataFrame(matches)
df_matches.rename(columns={'Date':'Matches_Played'},inplace=True)
df_matches.head()
# Out:
#            Matches_Played
# Team
# Argentina               4
# Australia               3
# Belgium                 7
# Brazil                  5
# Colombia                4

# %%
#merge the above 2 DataFrames to form a new: 'df_match'

df_match=pd.merge(df_matches,df_goals,how='outer',on='Team')
df_match.head()
# Out:
#            Matches_Played  Goal_Scored
# Team
# Argentina               4            6
# Australia               3            2
# Belgium                 7           16
# Brazil                  5            8
# Colombia                4            6

# %%
#getting goals per match DataFrame

df_match['Goals_Per_Match']= df_match['Goal_Scored']/df_match['Matches_Played']
df_match.head()
# Out:
#            Matches_Played  Goal_Scored  Goals_Per_Match
# Team
# Argentina               4            6         1.500000
# Australia               3            2         0.666667
# Belgium                 7           16         2.285714
# Brazil                  5            8         1.600000
# Colombia                4            6         1.500000

# %%
#getting goals conceded DataFrame

opp_goals=df_copy.groupby('Opponent')['Goal_Scored'].sum()   #groupby and sum
df_oppg=pd.DataFrame(opp_goals)                              #DF
df_oppg.rename(columns={'Goal_Scored':'Goal_Conceded'},inplace=True) #rename col
df_oppg.head()
# Out:
#            Goal_Conceded
# Opponent
# Argentina              9
# Australia              5
# Belgium                6
# Brazil                 3
# Colombia               3

# %%
df_oppg.index.names = ['Team'] #rename index
df_oppg.rename(columns={'Opponent':'Team'},inplace=True)  #rename col
df_match=pd.merge(df_match,df_oppg,how='outer',on='Team') #merge
df_match.head()
# Out:
#            Matches_Played  Goal_Scored  Goals_Per_Match  Goal_Conceded
# Team
# Argentina               4            6         1.500000              9
# Australia               3            2         0.666667              5
# Belgium                 7           16         2.285714              6
# Brazil                  5            8         1.600000              3
# Colombia                4            6         1.500000              3

# %%
#adding another column: 'Goals Conceded Per Match'

df_match['Goals_Conceded_Per_Match']=df_match['Goal_Conceded']/df_match['Matches_Played']
df_match.head()
# Out:
#            Matches_Played  Goal_Scored  Goals_Per_Match  Goal_Conceded  \
# Team
# Argentina               4            6         1.500000              9
# Australia               3            2         0.666667              5
# Belgium                 7           16         2.285714              6
# Brazil                  5            8         1.600000              3
# Colombia                4            6         1.500000              3
#
#            Goals_Conceded_Per_Match
# Team
# Argentina                  2.250000
# Australia                  1.666667
# Belgium                    0.857143
# Brazil                     0.600000
# Colombia                   0.750000

# %%
#x1=list(df_match.index.values)
#index=x1
#storing

# %%
df_comp=pd.DataFrame({'Goal_Scored':df_match['Goals_Per_Match'],'Goal_Conceded': df_match['Goals_Conceded_Per_Match']})
ax=df_comp.plot.bar(figsize=(12,4))
plt.xlabel("Teams")
plt.ylabel("Average Goals")
plt.title("Attack vs Defense")
# Out:
# Text(0.5,1,'Attack vs Defense')

# %% [markdown]
# ### Does "A More Disciplined Team is a Better Defensive Team" ?

# %%
df_copy['Discipline']=df_copy['Yellow_Card']+df_copy['Red']+df_copy['Yellow & Red']
df_copy1= df_copy[['Team','Discipline']]
df_copy1.head()
# Out:
#            Team  Discipline
# 0        Russia           0
# 1  Saudi Arabia           0
# 2         Egypt           2
# 3       Uruguay           0
# 4       Morocco           1

# %%
df_disc=pd.DataFrame(df_copy.groupby('Opponent')['Discipline'].sum())
df_disc.head()
# Out:
#            Discipline
# Opponent
# Argentina           9
# Australia           5
# Belgium            13
# Brazil             13
# Colombia            6

# %%
df_disc.index.names=['Team']

# %%
df_match=pd.merge(df_match,df_disc,how='outer',on='Team')
df_disc.rename(columns={'Opponent':'Team'},inplace=True)
df_match.head()
# Out:
#            Matches_Played  Goal_Scored  Goals_Per_Match  Goal_Conceded  \
# Team
# Argentina               4            6         1.500000              9
# Australia               3            2         0.666667              5
# Belgium                 7           16         2.285714              6
# Brazil                  5            8         1.600000              3
# Colombia                4            6         1.500000              3
#
#            Goals_Conceded_Per_Match  Discipline
# Team
# Argentina                  2.250000           9
# Australia                  1.666667           5
# Belgium                    0.857143          13
# Brazil                     0.600000          13
# Colombia                   0.750000           6

# %%
plt.scatter( x=df_match['Discipline'],y= df_match['Goal_Conceded'])
plt.xlabel('Discipline')
plt.ylabel('Goals Conceded')
plt.title('Goal Conceded vs Discipline')
# Out:
# Text(0.5,1,'Goal Conceded vs Discipline')

# %% [markdown]
# - Wanted to establish a relation between how disclipined a team is v/s How poor or good their defense is.
# - Though I was not establish a definite trend between the two features but in general, a better disciplined defense means a better defense.

# %% [markdown]
# ### Attack v/s Possession

# %%
df_copy.plot.scatter(x='Ball_Possession',c='r',y= 'Attempts',figsize=(8,8), marker='o')
plt.xlabel('Ball Possession')
plt.ylabel('Attempts')
plt.title('Attempts vs Possession')
# Out:
# Text(0.5,1,'Attempts vs Possession')

# %% [markdown]
# - Decided to plot this scatter graph to get a relation between Ball Possession and how good is the team moving forward
# - Generally, higher the ball possession, greater the number of goal attempts.

# %%
df_copy.plot(kind='scatter', x='Passes',c='g',y= 'Attempts',figsize=(8,8), marker='o')
plt.xlabel('Passes Completed')
plt.ylabel('Attempts')
plt.title('Attempts vs Passes')
# Out:
# Text(0.5,1,'Attempts vs Passes')
